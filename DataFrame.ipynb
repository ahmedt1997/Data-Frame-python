# %%
import pandas as pd

# %%
data=pd.read_csv('P4-Demographic-Data.csv')

# %%
data
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
#Number of rows
len(data)
# Out:
# 195

# %%
#see columns
data.columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %%
#number of columns
len(data.columns)
# Out:
# 5

# %%
#top rows
data.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
#bottom rows
data.tail()
# Out:
#          Country Name Country Code  Birth rate  Internet users  \
# 190       Yemen, Rep.          YEM      32.947            20.0
# 191      South Africa          ZAF      20.850            46.5
# 192  Congo, Dem. Rep.          COD      42.394             2.2
# 193            Zambia          ZMB      40.471            15.4
# 194          Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
#information on the columns
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    195 non-null    object
#  1   Country Code    195 non-null    object
#  2   Birth rate      195 non-null    float64
#  3   Internet users  195 non-null    float64
#  4   Income Group    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
#get stats on the columns. we have two numerical columns
data.describe()
# Out:
#        Birth rate  Internet users
# count  195.000000      195.000000
# mean    21.469928       42.076471
# std     10.605467       29.030788
# min      7.900000        0.900000
# 25%     12.120500       14.520000
# 50%     19.680000       41.000000
# 75%     29.759500       66.225000
# max     49.661000       96.546800

# %%
data.describe().transpose()
# Out:
#                 count       mean        std  min      25%    50%      75%  \
# Birth rate      195.0  21.469928  10.605467  7.9  12.1205  19.68  29.7595
# Internet users  195.0  42.076471  29.030788  0.9  14.5200  41.00  66.2250
#
#                     max
# Birth rate      49.6610
# Internet users  96.5468

# %%
###Reanaming columns of dataframe

# %%
data.columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %%
data.columns=['CountryName', 'CountryCode', 'Birthrate', 'Internetusers',
       'IncomeGroup']

# %%
data
# Out:
#               CountryName CountryCode  Birthrate  Internetusers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
##subsetting dataframe in pandas (rows)

# %%
# slicing rows
data[12:15]
# Out:
#      CountryName CountryCode  Birthrate  Internetusers  IncomeGroup
# 12       Belgium         BEL     11.200        82.1702  High income
# 13         Benin         BEN     36.440         4.9000   Low income
# 14  Burkina Faso         BFA     40.551         9.1000   Low income

# %%
#slicing from 170 to the end
data[170:]
# Out:
#                         CountryName CountryCode  Birthrate  Internetusers  \
# 170                      Tajikistan         TJK     30.792          16.00
# 171                    Turkmenistan         TKM     21.322           9.60
# 172                     Timor-Leste         TLS     35.755           1.10
# 173                           Tonga         TON     25.409          35.00
# 174             Trinidad and Tobago         TTO     14.590          63.80
# 175                         Tunisia         TUN     19.800          43.80
# 176                          Turkey         TUR     16.836          46.25
# 177                        Tanzania         TZA     39.518           4.40
# 178                          Uganda         UGA     43.474          16.20
# 179                         Ukraine         UKR     11.100          41.00
# 180                         Uruguay         URY     14.374          57.69
# 181                   United States         USA     12.500          84.20
# ...

# %%
#reverse dataframe
data[170::-1]
# Out:
#               CountryName CountryCode  Birthrate  Internetusers  \
# 170            Tajikistan         TJK     30.792          16.00
# 169              Thailand         THA     11.041          28.94
# 168                  Togo         TGO     36.080           4.50
# 167                  Chad         TCD     45.745           2.30
# 166  Syrian Arab Republic         SYR     24.043          26.20
# ..                    ...         ...        ...            ...
# 4    United Arab Emirates         ARE     11.044          88.00
# 3                 Albania         ALB     12.877          57.20
# 2                  Angola         AGO     45.985          19.10
# 1             Afghanistan         AFG     35.253           5.90
# 0                   Aruba         ABW     10.244          78.90
#
#              IncomeGroup
# 170  Lower middle income
# 169  Upper middle income
# 168           Low income
# 167           Low income
# 166  Lower middle income
# ..                   ...
# ...

# %%
#get only every 20th rows
data[::20]
# Out:
#     CountryName CountryCode  Birthrate  Internetusers          IncomeGroup
# 0         Aruba         ABW     10.244        78.9000          High income
# 20      Belarus         BLR     12.500        54.1700  Upper middle income
# 40   Costa Rica         CRI     15.022        45.9600  Upper middle income
# 60        Gabon         GAB     30.555         9.2000  Upper middle income
# 80        India         IND     20.291        15.1000  Lower middle income
# 100       Libya         LBY     21.425        16.5000  Upper middle income
# 120  Mozambique         MOZ     39.705         5.4000           Low income
# 140      Poland         POL      9.600        62.8492          High income
# 160    Suriname         SUR     18.455        37.4000  Upper middle income
# 180     Uruguay         URY     14.374        57.6900          High income

# %%
##subsetting dataframe in pandas (columns)

# %%
#subsetting one columns
data['CountryName'].head()
# Out:
# 0                   Aruba
# 1             Afghanistan
# 2                  Angola
# 3                 Albania
# 4    United Arab Emirates
# Name: CountryName, dtype: object

# %%
#subsetting multiple columns
data[['CountryName','Internetusers']].head(30)
# Out:
#                  CountryName  Internetusers
# 0                      Aruba       78.90000
# 1                Afghanistan        5.90000
# 2                     Angola       19.10000
# 3                    Albania       57.20000
# 4       United Arab Emirates       88.00000
# 5                  Argentina       59.90000
# 6                    Armenia       41.90000
# 7        Antigua and Barbuda       63.40000
# 8                  Australia       83.00000
# 9                    Austria       80.61880
# 10                Azerbaijan       58.70000
# 11                   Burundi        1.30000
# 12                   Belgium       82.17020
# 13                     Benin        4.90000
# 14              Burkina Faso        9.10000
# 15                Bangladesh        6.63000
# 16                  Bulgaria       53.06150
# 17                   Bahrain       90.00004
# 18              Bahamas, The       72.00000
# 19    Bosnia and Herzegovina       57.79000
# ...

# %%
#subsetting multiple columns
F=data[['CountryName','Internetusers']][:60]

# %%
F
# Out:
#                  CountryName  Internetusers
# 0                      Aruba      78.900000
# 1                Afghanistan       5.900000
# 2                     Angola      19.100000
# 3                    Albania      57.200000
# 4       United Arab Emirates      88.000000
# 5                  Argentina      59.900000
# 6                    Armenia      41.900000
# 7        Antigua and Barbuda      63.400000
# 8                  Australia      83.000000
# 9                    Austria      80.618800
# 10                Azerbaijan      58.700000
# 11                   Burundi       1.300000
# 12                   Belgium      82.170200
# 13                     Benin       4.900000
# 14              Burkina Faso       9.100000
# 15                Bangladesh       6.630000
# 16                  Bulgaria      53.061500
# 17                   Bahrain      90.000040
# 18              Bahamas, The      72.000000
# 19    Bosnia and Herzegovina      57.790000
# ...

# %%
F.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CountryName    60 non-null     object
#  1   Internetusers  60 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 1.1+ KB

# %%
#Matematical operations
data[['Birthrate','Internetusers','IncomeGroup']]
# Out:
#      Birthrate  Internetusers          IncomeGroup
# 0       10.244           78.9          High income
# 1       35.253            5.9           Low income
# 2       45.985           19.1  Upper middle income
# 3       12.877           57.2  Upper middle income
# 4       11.044           88.0          High income
# ..         ...            ...                  ...
# 190     32.947           20.0  Lower middle income
# 191     20.850           46.5  Upper middle income
# 192     42.394            2.2           Low income
# 193     40.471           15.4  Lower middle income
# 194     35.715           18.5           Low income
#
# [195 rows x 3 columns]

# %%
result=data.Birthrate*data.Internetusers

# %%
data['results']=result

# %%
data
# Out:
#               CountryName CountryCode  Birthrate  Internetusers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup   results
# 0            High income  808.2516
# 1             Low income  207.9927
# 2    Upper middle income  878.3135
# 3    Upper middle income  736.5644
# ...

# %%
#delete one column
data=data.drop('results',1)

# %%
data.head()
# Out:
#             CountryName CountryCode  Birthrate  Internetusers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
#filtering data

# %%
###filtering is about rows

# %%
filter = data.Internetusers>50

# %%
data[filter]
# Out:
#                         CountryName CountryCode  Birthrate  Internetusers  \
# 0                             Aruba         ABW     10.244          78.90
# 3                           Albania         ALB     12.877          57.20
# 4              United Arab Emirates         ARE     11.044          88.00
# 5                         Argentina         ARG     17.716          59.90
# 7               Antigua and Barbuda         ATG     16.447          63.40
# ..                              ...         ...        ...            ...
# 174             Trinidad and Tobago         TTO     14.590          63.80
# 180                         Uruguay         URY     14.374          57.69
# 181                   United States         USA     12.500          84.20
# 183  St. Vincent and the Grenadines         VCT     16.306          52.00
# 184                   Venezuela, RB         VEN     19.842          54.90
#
#              IncomeGroup
# 0            High income
# 3    Upper middle income
# ...

# %%
### or we can make it like this :
data[data['Internetusers']>80]
# Out:
#               CountryName CountryCode  Birthrate  Internetusers  IncomeGroup
# 4    United Arab Emirates         ARE     11.044       88.00000  High income
# 8               Australia         AUS     13.200       83.00000  High income
# 9                 Austria         AUT      9.400       80.61880  High income
# 12                Belgium         BEL     11.200       82.17020  High income
# 17                Bahrain         BHR     15.040       90.00004  High income
# 22                Bermuda         BMU     10.400       95.30000  High income
# 30                 Canada         CAN     10.900       85.80000  High income
# 31            Switzerland         CHE     10.200       86.34000  High income
# 45                Germany         DEU      8.500       84.17000  High income
# 47                Denmark         DNK     10.000       94.62970  High income
# 56                Finland         FIN     10.700       91.51440  High income
# ...

# %%
#even more interesting

# %%
filter2 = data.IncomeGroup=="High income"

# %%
filter2
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Name: IncomeGroup, Length: 195, dtype: bool

# %%
filter3 = data.Birthrate>25

# %%
data3=data[filter2 & filter3]

# %%
data3
# Out:
#           CountryName CountryCode  Birthrate  Internetusers  IncomeGroup
# 67  Equatorial Guinea         GNQ     35.362           16.4  High income

# %%
data3['CountryName']
# Out:
# 67    Equatorial Guinea
# Name: CountryName, dtype: object

# %%
#how to get unique categorie of a columns

# %%
data.IncomeGroup.unique()
# Out:
# array(['High income', 'Low income', 'Upper middle income',
#        'Lower middle income'], dtype=object)

# %%
len(data[data['IncomeGroup']=="Upper middle income"])
# Out:
# 48

# %%
#exemple of display every things about MALTA country
data[data.CountryName=="Malta"]
# Out:
#     CountryName CountryCode  Birthrate  Internetusers  IncomeGroup
# 116       Malta         MLT        9.5        68.9138  High income

# %%
##Accessing individual element
## there is a difference between thoes function , watch video number 044 for more details

# %%
data.at[12,'IncomeGroup']
# Out:
# 'High income'

# %%
data.iat[12,4]
# Out:
# 'High income'

# %%
###Introduction Seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams["figure.figsize"] = (5,5)

# %%
#Distrubution

# %%
visu1=sns.distplot(data["Internetusers"])

# %%
visu2=sns.boxplot(data=data,x="IncomeGroup",y="Birthrate")

# %%
#seaborn gallery

# %%
data.head()
# Out:
#             CountryName CountryCode  Birthrate  Internetusers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
# very important 
sns.lmplot(data=data,x="Internetusers",y="Birthrate",fit_reg=False,\
           hue="IncomeGroup" )

# %%
filtre=data.Internetusers<5

# %%
filtre
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192     True
# 193    False
# 194    False
# Name: Internetusers, Length: 195, dtype: bool

# %%
data[filtre &(data.IncomeGroup=="Lower middle income") ]
# Out:
#      CountryName CountryCode  Birthrate  Internetusers          IncomeGroup
# 117      Myanmar         MMR     18.119            1.6  Lower middle income
# 172  Timor-Leste         TLS     35.755            1.1  Lower middle income
